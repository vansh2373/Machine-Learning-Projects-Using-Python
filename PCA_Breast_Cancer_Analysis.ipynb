# %% [markdown]
# # PCA on Breast Cancer Dataset: Analysis and Visualization
#
# ## ✅ Problem Statement
# To reduce the dimensionality of the breast cancer dataset using Principal Component Analysis (PCA)
# and visualize it in a two-dimensional space, while preserving maximum variance in the data.
#
# ## 🎯 Objectives
# 1. Apply PCA to reduce high-dimensional data (30 features) into 2D.
# 2. Visualize the breast cancer dataset using the top two principal components.
# 3. Understand class separability using visual representation.
#
# ## 🔧 Methodology
# 1. Load the dataset from scikit-learn.
# 2. Normalize the data (important before PCA).
# 3. Apply PCA to reduce features from 30 to 2.
# 4. Visualize the reduced data using a scatter plot, color-coded by target class.

# %%
# Step 1: Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# Step 2: Load Dataset
data = load_breast_cancer()
X = data.data
y = data.target


# Step 3: Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# Step 4: Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


# Step 5: Print explained variance
print("Explained variance ratio of the 2 components:", pca.explained_variance_ratio_)


# Step 6: Plotting the 2D data
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='coolwarm', edgecolors='k')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('2D PCA of Breast Cancer Dataset')
plt.grid(True)
plt.colorbar(label='Target (0 = Malignant, 1 = Benign)')
plt.show()
# Out:
# Explained variance ratio of the 2 components: [0.44272026 0.18971182]

# %% [markdown]
# ## ✅ Conclusion
# PCA effectively reduced the 30-dimensional dataset into 2D for visualization.
# A clear visual separation is often seen between benign and malignant classes.
# It’s a powerful preprocessing technique before applying machine learning algorithms for efficiency and noise reduction.
